# %%
import pandas as pd
import scipy.stats as st
import math

# %% [markdown]
# # Business Problem

# %% [markdown]
# E-ticaretteki en önemli problemlerden bir tanesi ürünlere satış
# sonrası verilen puanların doğru şekilde hesaplanmasıdır. Bu
# problemin çözümü e-ticaret sitesi için daha fazla müşteri
# memnuniyeti sağlamak, satıcılar için ürünün öne çıkması ve satın
# alanlar için sorunsuz bir alışveriş deneyimi demektir. Bir diğer
# problem ise ürünlere verilen yorumların doğru bir şekilde
# sıralanması olarak karşımıza çıkmaktadır. Yanıltıcı yorumların öne
# çıkması ürünün satışını doğrudan etkileyeceğinden dolayı hem
# maddi kayıp hem de müşteri kaybına neden olacaktır. Bu 2 temel
# problemin çözümünde e-ticaret sitesi ve satıcılar satışlarını
# arttırırken müşteriler ise satın alma yolculuğunu sorunsuz olarak
# tamamlayacaktır.

# %% [markdown]
# # Dataset

# %% [markdown]
# Amazon ürün verilerini içeren bu veri seti ürün kategorileri ile çeşitli metadataları içermektedir. Elektronik kategorisindeki en
# fazla yorum alan ürünün kullanıcı puanları ve yorumları vardır.

# %% [markdown]
# * reviewerID Kullanıcı ID’si
# * asin Ürün ID’si
# * reviewerName Kullanıcı Adı
# * helpful Faydalı değerlendirme derecesi
# * reviewText Değerlendirme
# * overall Ürün rating’i
# * summary Değerlendirme özeti
# * unixReviewTime Değerlendirme zamanı
# * reviewTime Değerlendirme zamanı Raw
# * day_diff Değerlendirmeden itibaren geçen gün sayısı
# * helpful_yes Değerlendirmenin faydalı bulunma sayısı
# * total_vote Değerlendirmeye verilen oy sayısı

# %%
df = pd.read_csv('../input/amazon-reviews/amazon_reviews.csv')

# %%
df.head()
# Out:
#        reviewerID        asin  reviewerName helpful  \
# 0  A3SBTW3WS4IQSN  B007WTAJTO           NaN  [0, 0]
# 1  A18K1ODH1I2MVB  B007WTAJTO          0mie  [0, 0]
# 2  A2FII3I2MBMUIA  B007WTAJTO           1K3  [0, 0]
# 3   A3H99DFEG68SR  B007WTAJTO           1m2  [0, 0]
# 4  A375ZM4U047O79  B007WTAJTO  2&amp;1/2Men  [0, 0]
#
#                                           reviewText  overall  \
# 0                                         No issues.      4.0
# 1  Purchased this for my device, it worked as adv...      5.0
# 2  it works as expected. I should have sprung for...      4.0
# 3  This think has worked out great.Had a diff. br...      5.0
# 4  Bought it with Retail Packaging, arrived legit...      5.0
#
#                                   summary  unixReviewTime  reviewTime  \
# 0                              Four Stars      1406073600  2014-07-23
# 1                           MOAR SPACE!!!      1382659200  2013-10-25
# 2               nothing to really say....      1356220800  2012-12-23
# 3  Great buy at this price!!!  *** UPDATE      1384992000  2013-11-21
# 4                        best deal around      1373673600  2013-07-13
#
#    day_diff  helpful_yes  total_vote
# 0       138            0           0
# 1       409            0           0
# 2       715            0           0
# 3       382            0           0
# 4       513            0           0

# %%
df.dtypes
# Out:
# reviewerID         object
# asin               object
# reviewerName       object
# helpful            object
# reviewText         object
# overall           float64
# summary            object
# unixReviewTime      int64
# reviewTime         object
# day_diff            int64
# helpful_yes         int64
# total_vote          int64
# dtype: object

# %%
df.reviewTime = pd.to_datetime(df.reviewTime)

# %% [markdown]
# ### Average Rating’i güncel yorumlara göre hesaplayınız ve var olan average rating ile kıyaslayınız.

# %%
df.overall.mean()
# Out:
# 4.587589013224822

# %%
current_date = df.reviewTime.max()
current_date
# Out:
# Timestamp('2014-12-07 00:00:00')

# %%
df['recency'] = df.reviewTime.apply(lambda x: (current_date - x).days)

# %%
df.recency.quantile([0.1,0.25,0.5])
# Out:
# 0.10    166.0
# 0.25    280.0
# 0.50    430.0
# Name: recency, dtype: float64

# %%
def weighted_rating(dataframe,w1=28,w2=26,w3=24,w4=22):
    
    dataframe['weights'] = pd.qcut(dataframe.recency,[0,0.1,0.25,0.5,1],labels =[w1,w2,w3,w4])
    
    weight_overall = dataframe.groupby('weights').agg({'overall':'mean'}).reset_index()
    
    weighted_score_by_time =  weight_overall.apply(lambda x: x.weights * x.overall / 100,axis=1)
    
    return weighted_score_by_time.sum()

# %%
weighted_rating(df)
# Out:
# 4.63977000023405

# %%
df.groupby('weights').agg({'overall':'mean'})
# Out:
#           overall
# weights
# 28       4.689861
# 26       4.699864
# 24       4.636141
# 22       4.508958

# %% [markdown]
# ## Ürün için ürün detay sayfasında görüntülenecek 20 review’i belirleyiniz.

# %%
df['helpful_no'] = df.total_vote - df.helpful_yes

# %%
def wilson_lower_bound(up, down, confidence=0.95):
    """
    Wilson Lower Bound Score hesapla

    - Bernoulli parametresi p için hesaplanacak güven aralığının alt sınırı WLB skoru olarak kabul edilir.
    - Hesaplanacak skor ürün sıralaması için kullanılır.
    - Not:
    Eğer skorlar 1-5 arasıdaysa 1-3 negatif, 4-5 pozitif olarak işaretlenir ve bernoulli'ye uygun hale getirilebilir.
    Bu beraberinde bazı problemleri de getirir. Bu sebeple bayesian average rating yapmak gerekir.

    Parameters
    ----------
    up: int
        up count
    down: int
        down count
    confidence: float
        confidence

    Returns
    -------
    wilson score: float

    """
    n = up + down
    if n == 0:
        return 0
    z = st.norm.ppf(1 - (1 - confidence) / 2)
    phat = 1.0 * up / n
    return (phat + z * z / (2 * n) - z * math.sqrt((phat * (1 - phat) + z * z / (4 * n)) / n)) / (1 + z * z / n)

# %%
df['score_pos_neg_diff '] = df.helpful_yes - df.helpful_no

df['score_average_rating'] = df.apply(lambda x : x.helpful_yes / x.total_vote if x.total_vote != 0 else 0,axis=1)

df['wilson_lower_bound'] = df.apply(lambda x: wilson_lower_bound(x.helpful_yes,x.helpful_no),axis=1)

# %%
df.sort_values('wilson_lower_bound',ascending= False).head(20)
# Out:
#           reviewerID        asin                          reviewerName  \
# 2031  A12B7ZMXFI6IXY  B007WTAJTO                  Hyoun Kim "Faluzure"
# 3449   AOEAD7DPLZE53  B007WTAJTO                     NLee the Engineer
# 4212   AVBMZZAFEKO58  B007WTAJTO                           SkincareCEO
# 317   A1ZQAQFYSXL5MQ  B007WTAJTO               Amazon Customer "Kelly"
# 4672  A2DKQQIZ793AV5  B007WTAJTO                               Twister
# 1835  A1J6VSUM80UAF8  B007WTAJTO                           goconfigure
# 3981  A1K91XXQ6ZEBQR  B007WTAJTO            R. Sutton, Jr. "RWSynergy"
# 3807   AFGRMORWY2QNX  B007WTAJTO                            R. Heisler
# 4306   AOHXKM5URSKAB  B007WTAJTO                         Stellar Eller
# 4596  A1WTQUOQ4WG9AI  B007WTAJTO           Tom Henriksen "Doggy Diner"
# 315   A2J26NNQX6WKAU  B007WTAJTO            Amazon Customer "johncrea"
# 1465   A6I8KXYK24RTB  B007WTAJTO                              D. Stein
# 1609  A2TPXOZSU1DACQ  B007WTAJTO                                Eskimo
# 4302  A2EL2GWJ9T0DWY  B007WTAJTO                             Stayeraug
# 4072  A22GOZTFA02O2F  B007WTAJTO                           sb21 "sb21"
# 1072  A2O96COBMVY9C4  B007WTAJTO                        Crysis Complex
# 2583  A3MEPYZVTAV90W  B007WTAJTO                               J. Wong
# 121   A2Z4VVF1NTJWPB  B007WTAJTO                                A. Lee
# 1142  A1PLHPPAJ5MUXG  B007WTAJTO  Daniel Pham(Danpham_X @ yahoo.  com)
# 1753   ALPLKR59QMBUX  B007WTAJTO                             G. Becker
#
#            helpful                                         reviewText  \
# 2031  [1952, 2020]  [[ UPDATE - 6/19/2014 ]]So my lovely wife boug...
# 3449  [1428, 1505]  I have tested dozens of SDHC and micro-SDHC ca...
# 4212  [1568, 1694]  NOTE:  please read the last update (scroll to ...
# 317     [422, 495]  If your card gets hot enough to be painful, it...
# 4672      [45, 49]  Sandisk announcement of the first 128GB micro ...
# 1835      [60, 68]  Bought from BestBuy online the day it was anno...
# 3981    [112, 139]  The last few days I have been diligently shopp...
# 3807      [22, 25]  I bought this card to replace a lost 16 gig in...
# 4306      [51, 65]  While I got this card as a "deal of the day" o...
# 4596     [82, 109]  Hi:I ordered two card and they arrived the nex...
# 315       [38, 48]  Bought this card to use with my Samsung Galaxy...
# 1465        [7, 7]  I for one have not bought into Google's, or an...
# 1609        [7, 7]  I have always been a sandisk guy.  This cards ...
# 4302      [14, 16]  So I got this SD specifically for my GoPro Bla...
# 4072        [6, 6]  I used this for my Samsung Galaxy Tab 2 7.0 . ...
# 1072        [5, 5]  What more can I say? The 64GB micro SD works f...
# 2583        [5, 5]  I bought this Class 10 SD card for my GoPro 3 ...
# 121         [5, 5]  Update: providing an update with regard to San...
# 1142        [5, 5]  As soon as I saw that this card was announced ...
# 1753        [5, 5]  Puchased this card right after I received my S...
#
#       overall                                            summary  \
# 2031      5.0  UPDATED - Great w/ Galaxy S4 & Galaxy Tab 4 10...
# 3449      5.0  Top of the class among all (budget-priced) mic...
# 4212      1.0  1 Star reviews - Micro SDXC card unmounts itse...
# 317       1.0                                Warning, read this!
# 4672      5.0  Super high capacity!!!  Excellent price (on Am...
# 1835      5.0                                           I own it
# 3981      5.0  Resolving confusion between "Mobile Ultra" and...
# 3807      3.0   Good buy for the money but wait, I had an issue!
# 4306      5.0                                      Awesome Card!
# 4596      1.0     Designed incompatibility/Don't support SanDisk
# 315       5.0  Samsung Galaxy Tab2 works with this card if re...
# 1465      4.0                                           Finally.
# 1609      5.0                  Bet you wish you had one of these
# 4302      5.0                        Perfect with GoPro Black 3+
# 4072      5.0               Used for my Samsung Galaxy Tab 2 7.0
# 1072      5.0               Works wonders for the Galaxy Note 2!
# 2583      5.0                  Works Great with a GoPro 3 Black!
# 121       5.0                     ready for use on the Galaxy S3
# 1142      5.0                          Great large capacity card
# 1753      5.0                    Use Nothing Other Than the Best
#
#       unixReviewTime reviewTime  day_diff  helpful_yes  total_vote  recency  \
# 2031      1367366400 2013-01-05       702         1952        2020      701
# 3449      1348617600 2012-09-26       803         1428        1505      802
# 4212      1375660800 2013-05-08       579         1568        1694      578
# 317       1346544000 2012-02-09      1033          422         495     1032
# 4672      1394150400 2014-07-03       158           45          49      157
# 1835      1393545600 2014-02-28       283           60          68      282
# 3981      1350864000 2012-10-22       777          112         139      776
# 3807      1361923200 2013-02-27       649           22          25      648
# 4306      1339200000 2012-09-06       823           51          65      822
# 4596      1348272000 2012-09-22       807           82         109      806
# 315       1344816000 2012-08-13       847           38          48      846
# 1465      1397433600 2014-04-14       238            7           7      237
# 1609      1395792000 2014-03-26       257            7           7      256
# 4302      1395360000 2014-03-21       262           14          16      261
# 4072      1347321600 2012-11-09       759            6           6      758
# 1072      1349395200 2012-05-10       942            5           5      941
# 2583      1370649600 2013-08-06       489            5           5      488
# 121       1346803200 2012-05-09       943            5           5      942
# 1142      1396396800 2014-02-04       307            5           5      306
# 1753      1350864000 2012-10-22       777            5           5      776
#
#      weights  helpful_no  score_pos_neg_diff   score_average_rating  \
# 2031      22          68                 1884              0.966337
# 3449      22          77                 1351              0.948837
# 4212      22         126                 1442              0.925620
# 317       22          73                  349              0.852525
# 4672      28           4                   41              0.918367
# 1835      24           8                   52              0.882353
# 3981      22          27                   85              0.805755
# 3807      22           3                   19              0.880000
# 4306      22          14                   37              0.784615
# 4596      22          27                   55              0.752294
# 315       22          10                   28              0.791667
# 1465      26           0                    7              1.000000
# 1609      26           0                    7              1.000000
# 4302      26           2                   12              0.875000
# 4072      22           0                    6              1.000000
# 1072      22           0                    5              1.000000
# 2583      22           0                    5              1.000000
# 121       22           0                    5              1.000000
# 1142      24           0                    5              1.000000
# 1753      22           0                    5              1.000000
#
#       wilson_lower_bound
# 2031            0.957544
# 3449            0.936519
# 4212            0.912139
# 317             0.818577
# 4672            0.808109
# 1835            0.784651
# 3981            0.732136
# 3807            0.700442
# 4306            0.670334
# 4596            0.663595
# 315             0.657411
# 1465            0.645670
# 1609            0.645670
# 4302            0.639772
# 4072            0.609666
# 1072            0.565518
# 2583            0.565518
# 121             0.565518
# 1142            0.565518
# 1753            0.565518
